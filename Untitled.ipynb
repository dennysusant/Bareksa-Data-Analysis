# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.dates as mdates
# %matplotlib inline

# %%
data=pd.read_csv('train_data_de.csv',sep=';',parse_dates=['date'])
data.head()
# Out:
#         date sku  Price Store  promo_item  promo_card  qty
# 0 2016-01-06  sg   2120    tb           0           1   24
# 1 2016-01-06  sg   2120    tc           0           1   16
# 2 2016-01-06  sg   2120    ta           0           0   29
# 3 2016-02-06  sg   2120    ta           0           1   25
# 4 2016-02-06  sg   2120    tc           0           0   10

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2397 entries, 0 to 2396
# Data columns (total 7 columns):
# date          2397 non-null datetime64[ns]
# sku           2397 non-null object
# Price         2397 non-null int64
# Store         2397 non-null object
# promo_item    2397 non-null int64
# promo_card    2397 non-null int64
# qty           2397 non-null int64
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 131.2+ KB

# %%
data.describe()
# Out:
#              Price   promo_item   promo_card          qty
# count  2397.000000  2397.000000  2397.000000  2397.000000
# mean   2266.128494     0.056320     0.598248    16.443054
# std     151.165302     0.230587     0.490355    11.713138
# min    2000.000000     0.000000     0.000000     1.000000
# 25%    2200.000000     0.000000     0.000000     9.000000
# 50%    2300.000000     0.000000     1.000000    14.000000
# 75%    2300.000000     0.000000     1.000000    21.000000
# max    4100.000000     1.000000     1.000000   128.000000

# %%
data['Store'].unique()
# Out:
# array(['tb', 'tc', 'ta'], dtype=object)

# %%
dfTB=data[data['Store']=='tb']
dfTB=dfTB.sort_values('date')
dfTC=data[data['Store']=='tc']
dfTC=dfTC.sort_values('date')
dfTA=data[data['Store']=='ta']
dfTA=dfTA.sort_values('date')

# %%
plt.figure(figsize=(20,20))
plt.subplot(311)
plt.title('Store TB')
plt.style.use('seaborn')
plt.plot(dfTB['date'],dfTB['Price'])
ax=plt.gca()
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %y'))
plt.subplot(312)
plt.title('Store TC')
plt.style.use('seaborn')
plt.plot(dfTC['date'],dfTC['Price'])
ax=plt.gca()
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %y'))
plt.subplot(313)
plt.title('Store TA')
plt.style.use('seaborn')
plt.plot(dfTA['date'],dfTA['Price'])
ax=plt.gca()
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %y'))
plt.show()
# Out:
# C:\Users\Denny\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(20,20))
plt.subplot(311)
plt.title('Store TB')
plt.style.use('seaborn')
plt.plot(dfTB['date'],dfTB['qty'])
ax=plt.gca()
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %y'))
plt.subplot(312)
plt.title('Store TC')
plt.style.use('seaborn')
plt.plot(dfTC['date'],dfTC['qty'])
ax=plt.gca()
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %y'))
plt.subplot(313)
plt.title('Store TA')
plt.style.use('seaborn')
plt.plot(dfTA['date'],dfTA['qty'])
ax=plt.gca()
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %y'))
plt.show()

# %%
sns.distplot(data[data['promo_item']==0]['qty'],kde=True,color='blue',bins=20)
sns.distplot(data[data['promo_item']==1]['qty'],kde=True,color='red',bins=20)

# %%
sns.distplot(data[data['promo_card']==0]['qty'],kde=True,color='blue',bins=20)
sns.distplot(data[data['promo_card']==1]['qty'],kde=True,color='red',bins=20)

# %%
sns.distplot(data[data['Store']=='tb']['qty'],kde=True,color='blue',bins=20)
sns.distplot(data[data['Store']=='tc']['qty'],kde=True,color='red',bins=20)
sns.distplot(data[data['Store']=='ta']['qty'],kde=True,color='yellow',bins=20)

# %%
plt.scatter(data['Price'],data['qty'])

# %%
data.head()
# Out:
#         date sku  Price Store  promo_item  promo_card  qty
# 0 2016-01-06  sg   2120    tb           0           1   24
# 1 2016-01-06  sg   2120    tc           0           1   16
# 2 2016-01-06  sg   2120    ta           0           0   29
# 3 2016-02-06  sg   2120    ta           0           1   25
# 4 2016-02-06  sg   2120    tc           0           0   10

# %%
sns.FacetGrid(data,col='promo_item',row='promo_card').map(sns.countplot,'qty').fig.set_size_inches(15,10)
# Out:
# C:\Users\Denny\Anaconda3\lib\site-packages\seaborn\axisgrid.py:715: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
corr=data.corr()
sns.heatmap(corr,annot=True)

# %%
data.head()
df=data[['Price','Store','promo_item','promo_card','qty']]
store=pd.get_dummies(df['Store'])
df=pd.concat([df,store],axis=1)
df=df.drop('Store',axis=1)
df
# Out:
#       Price  promo_item  promo_card  qty  ta  tb  tc
# 0      2120           0           1   24   0   1   0
# 1      2120           0           1   16   0   0   1
# 2      2120           0           0   29   1   0   0
# 3      2120           0           1   25   1   0   0
# 4      2120           0           0   10   0   0   1
# 5      2120           0           1   10   0   1   0
# 6      2120           0           1   33   1   0   0
# 7      2120           0           0   15   0   0   1
# 8      2120           0           0   15   0   1   0
# 9      2120           0           1   48   1   0   0
# 10     2120           0           1   70   0   1   0
# 11     2120           0           1   47   0   0   1
# 12     2120           0           1   35   0   0   1
# 13     2120           0           1   79   0   1   0
# 14     2120           0           1   95   1   0   0
# 15     2120           0           1   22   0   1   0
# 16     2120           0           1   42   1   0   0
# ...

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
label=preprocessing.LabelEncoder()
xtrain,xtes,ytrain,ytes=train_test_split(df.drop('qty',axis=1),data['qty'],test_size=0.30,random_state=101)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
lm = LinearRegression()
lm.fit(xtrain, ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
coeff_df = pd.DataFrame(lm.coef_,xtrain.columns,columns=['Coefficient'])
coeff_df
# Out:
#             Coefficient
# Price         -0.006637
# promo_item     8.030456
# promo_card     8.443351
# ta             0.582702
# tb             2.297429
# tc            -2.880131

# %%
predictions = lm.predict(xtrain)
plt.scatter(ytrain,predictions)

# %%
sns.distplot((ytrain-predictions),bins=50);

# %%
print('MAE:', mean_absolute_error(ytrain, predictions))
print('MSE:', mean_squared_error(ytrain, predictions))
print('RMSE:', np.sqrt(mean_squared_error(ytrain, predictions)))
print('R2 Score :', r2_score(ytrain, predictions))
# Out:
# MAE: 7.33421135725806
# MSE: 105.89362529776938
# RMSE: 10.29046283204839
# R2 Score : 0.2194158885210431

# %%
predictions = lm.predict(xtes)
plt.scatter(ytes,predictions)

# %%
sns.distplot((ytes-predictions),bins=50);

# %%
print('MAE:', mean_absolute_error(ytes, predictions))
print('MSE:', mean_squared_error(ytes, predictions))
print('RMSE:', np.sqrt(mean_squared_error(ytes, predictions)))
print('R2 Score :', r2_score(ytes, predictions))
# Out:
# MAE: 7.344709916224873
# MSE: 107.55123072151615
# RMSE: 10.37069094716047
# R2 Score : 0.23474531151638633

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge
rlm = Ridge(alpha=0.1)
rlm.fit(xtrain, ytrain)
# Out:
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
coeff_df = pd.DataFrame(rlm.coef_,xtrain.columns,columns=['Coefficient'])
coeff_df
# Out:
#             Coefficient
# Price         -0.006637
# promo_item     8.021560
# promo_card     8.441659
# ta             0.582234
# tb             2.297414
# tc            -2.879648

# %%
predictions = rlm.predict(xtrain)
plt.scatter(ytrain,predictions)

# %%
sns.distplot((ytrain-predictions),bins=50);

# %%
print('MAE:', mean_absolute_error(ytrain, predictions))
print('MSE:', mean_squared_error(ytrain, predictions))
print('RMSE:', np.sqrt(mean_squared_error(ytrain, predictions)))
print('R2 Score :', r2_score(ytrain, predictions))
# Out:
# MAE: 7.334249286808252
# MSE: 105.89363050628346
# RMSE: 10.290463085123209
# R2 Score : 0.21941585012701015

# %%
predictions = rlm.predict(xtes)
plt.scatter(ytes,predictions)

# %%
sns.distplot((ytes-predictions),bins=50);

# %%
print('MAE:', mean_absolute_error(ytes, predictions))
print('MSE:', mean_squared_error(ytes, predictions))
print('RMSE:', np.sqrt(mean_squared_error(ytes, predictions)))
print('R2 Score :', r2_score(ytes, predictions))
# Out:
# MAE: 7.344624284391435
# MSE: 107.55086120528702
# RMSE: 10.370673131734845
# R2 Score : 0.23474794071946392

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
llm = Lasso(alpha=0.1)
llm.fit(xtrain, ytrain)
# Out:
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
coeff_df = pd.DataFrame(llm.coef_,xtrain.columns,columns=['Coefficient'])
coeff_df
# Out:
#             Coefficient
# Price         -0.006509
# promo_item     6.180431
# promo_card     8.165877
# ta             0.000000
# tb             1.556837
# tc            -3.098244

# %%
predictions = llm.predict(xtrain)
plt.scatter(ytrain,predictions)

# %%
sns.distplot((ytrain-predictions),bins=50);

# %%
print('MAE:', mean_absolute_error(ytrain, predictions))
print('MSE:', mean_squared_error(ytrain, predictions))
print('RMSE:', np.sqrt(mean_squared_error(ytrain, predictions)))
print('R2 Score :', r2_score(ytrain, predictions))
# Out:
# MAE: 7.349565837513641
# MSE: 106.15863600834098
# RMSE: 10.303331306346553
# R2 Score : 0.21746238896465098

# %%
predictions = llm.predict(xtes)
plt.scatter(ytes,predictions)

# %%
sns.distplot((ytes-predictions),bins=50);

# %%
print('MAE:', mean_absolute_error(ytes, predictions))
print('MSE:', mean_squared_error(ytes, predictions))
print('RMSE:', np.sqrt(mean_squared_error(ytes, predictions)))
print('R2 Score :', r2_score(ytes, predictions))
# Out:
# MAE: 7.3343529669751675
# MSE: 107.81021759395094
# RMSE: 10.383169920306175
# R2 Score : 0.23290255326009435

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor(random_state=101, n_estimators=100, learning_rate=0.1)
gbr.fit(xtrain, ytrain)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=101, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
predictions = gbr.predict(xtrain)
plt.scatter(ytrain,predictions)

# %%
sns.distplot((ytrain-predictions),bins=50);

# %%
print('MAE:', mean_absolute_error(ytrain, predictions))
print('MSE:', mean_squared_error(ytrain, predictions))
print('RMSE:', np.sqrt(mean_squared_error(ytrain, predictions)))
print('R2 Score :', r2_score(ytrain, predictions))
# Out:
# MAE: 7.010738584379679
# MSE: 97.43229045276362
# RMSE: 9.870779627403483
# R2 Score : 0.28178775956939295

# %%
predictions = gbr.predict(xtes)
plt.scatter(ytes,predictions)

# %%
sns.distplot((ytes-predictions),bins=50);

# %%
print('MAE:', mean_absolute_error(ytes, predictions))
print('MSE:', mean_squared_error(ytes, predictions))
print('RMSE:', np.sqrt(mean_squared_error(ytes, predictions)))
print('R2 Score :', r2_score(ytes, predictions))
# Out:
# MAE: 7.182323742820606
# MSE: 102.48444791358872
# RMSE: 10.123460273720085
# R2 Score : 0.2707967753005096

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBRegressor
xgbr = XGBRegressor(random_state=101)
xgbr.fit(xtrain, ytrain)
# Out:
# C:\Users\Denny\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [19:08:27] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=101,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
predictions = xgbr.predict(xtes)
plt.scatter(ytes,predictions)

# %%
sns.distplot((ytes-predictions),bins=50);

# %%
print('MAE:', mean_absolute_error(ytes, predictions))
print('MSE:', mean_squared_error(ytes, predictions))
print('RMSE:', np.sqrt(mean_squared_error(ytes, predictions)))
# Out:
# MAE: 7.1781408561600575
# MSE: 102.71253615854536
# RMSE: 10.134719342860233

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(random_state=101)
rfr.fit(xtrain,ytrain)
# Out:
# C:\Users\Denny\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=101, verbose=0,
#                       warm_start=False)

# %%
predictions = rfr.predict(xtes)
plt.scatter(ytes,predictions)

# %%
sns.distplot((ytes-predictions),bins=50);

# %%
print('MAE:', mean_absolute_error(ytes, predictions))
print('MSE:', mean_squared_error(ytes, predictions))
print('RMSE:', np.sqrt(mean_squared_error(ytes, predictions)))
# Out:
# MAE: 7.296326129703358
# MSE: 105.84095213897193
# RMSE: 10.287903194479036

# %% [markdown]
# # Deep Learning

# %%
import keras
from keras.layers import Dense
from keras.models import Sequential, load_model
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
len(xtrain)
# Out:
# 1677

# %%
model = Sequential()
# The Input Layer :
model.add(Dense(256, kernel_initializer='normal',input_dim = xtrain.shape[1], activation='relu'))

# The Hidden Layers :
model.add(Dense(512, kernel_initializer='normal',activation='relu'))
model.add(Dense(512, kernel_initializer='normal',activation='relu'))
model.add(Dense(512, kernel_initializer='normal',activation='relu'))

# The Output Layer :
model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 256)               1792
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 513
# ...
# Total params: 659,201
# Trainable params: 659,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', 
                             verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
fitresults = model.fit(xtrain, ytrain, epochs=250, batch_size=128, 
                       validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Train on 1341 samples, validate on 336 samples
# Epoch 1/250
# 1341/1341 [==============================] - 0s 200us/step - loss: 5268.9528 - mean_squared_error: 5268.9531 - val_loss: 228.2946 - val_mean_squared_error: 228.2946
#
# Epoch 00001: val_loss improved from inf to 228.29460, saving model to Weights-001--228.29460.hdf5
# Epoch 2/250
# 1341/1341 [==============================] - 0s 126us/step - loss: 286.7258 - mean_squared_error: 286.7257 - val_loss: 264.3083 - val_mean_squared_error: 264.3083
#
# Epoch 00002: val_loss did not improve from 228.29460
# Epoch 3/250
# 1341/1341 [==============================] - 0s 138us/step - loss: 178.2834 - mean_squared_error: 178.2834 - val_loss: 190.2221 - val_mean_squared_error: 190.2221
#
# Epoch 00003: val_loss improved from 228.29460 to 190.22214, saving model to Weights-003--190.22214.hdf5
# Epoch 4/250
# ...

# %%
plt.plot(fitresults.epoch,fitresults.history['loss'],label='train')
plt.plot(fitresults.epoch,fitresults.history['val_loss'],label='validation')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
# Load weights file of the best model :
weights_file = 'Weights-250--133.95212.hdf5' # choose the best checkpoint 
model.load_weights(weights_file) # load it
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# %%
model.save('dlm_bareksa.h5')

# %%
dlm = load_model('dlm_bareksa.h5')

# %%
predictions = dlm.predict(xtrain)
predictions = predictions.reshape(1677)
plt.scatter(ytrain,predictions)

# %%
sns.distplot((ytrain-predictions),bins=50);

# %%
print('MAE:', mean_absolute_error(ytrain, predictions))
print('MSE:', mean_squared_error(ytrain, predictions))
print('RMSE:', np.sqrt(mean_squared_error(ytrain, predictions)))
print('R2 Score :', r2_score(ytrain, predictions))
# Out:
# MAE: 7.567437469923717
# MSE: 112.16366707512223
# RMSE: 10.590734963878674
# R2 Score : 0.1731969119211927

# %%
predictions = dlm.predict(xtes)
predictions = predictions.reshape(720)
plt.scatter(ytes,predictions)

# %%
sns.distplot((ytes-predictions),bins=50);

# %%
print('MAE:', mean_absolute_error(ytes, predictions))
print('MSE:', mean_squared_error(ytes, predictions))
print('RMSE:', np.sqrt(mean_squared_error(ytes, predictions)))
print('R2 Score :', r2_score(ytes, predictions))
# Out:
# MAE: 7.531612065103319
# MSE: 113.00307620786846
# RMSE: 10.630290504396786
# R2 Score : 0.19595402766653358
